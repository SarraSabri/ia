# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("titanic-passengers.csv", delimiter=';')

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age'].fillna( df['Age'] . mean() , inplace=True)
df['Embarked'].fillna( df['Embarked'] .mode()[0], inplace=True)
df=df.drop(['Cabin'], axis=1)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex        Age  \
# 0                           Collander, Mr. Erik Gustaf    male  28.000000
# 1                              Moen, Mr. Sigurd Hansen    male  25.000000
# 2                               Jensen, Mr. Hans Peder    male  20.000000
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.000000
# 4                               Davidson, Mr. Thornton    male  31.000000
# ..                                                 ...     ...        ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# 887                              Sirayanian, Mr. Orsen    male  22.000000
# 888                                Cacic, Miss. Marija  female  30.000000
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male  29.699118
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.000000
#
#      SibSp  Parch      Ticket     Fare Embarked
# 0        0      0      248740  13.0000        S
# 1        0      0      348123   7.6500        S
# 2        0      0      350050   7.8542        S
# 3        0      4      349909  21.0750        S
# 4        1      0  F.C. 12750  52.0000        S
# ..     ...    ...         ...      ...      ...
# 886      1      0      237736  30.0708        C
# 887      0      0        2669   7.2292        C
# 888      0      0      315084   8.6625        S
# 889      0      0      349215   7.8958        S
# 890      0      0      250655  26.0000        S
#
# [891 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
grid=sns.FacetGrid(df,col='Survived')
grid.map(sns.barplot,'Sex','Age')
grid.add_legend()
# Out:
# C:\Users\sarra\anaconda3\lib\site-packages\seaborn\axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
grid=sns.FacetGrid(df,col='Survived')
grid.map(sns.barplot,'Parch','Age')
grid.add_legend()

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 76.7+ KB

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
df['Survived']=encoder.fit_transform(df['Survived'])
df['Sex']=encoder.fit_transform(df['Sex'])
df['Embarked']=encoder.fit_transform(df['Embarked'])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare  Embarked
# 0        0      248740  13.0000         2
# 1        0      348123   7.6500         2
# 2        0      350050   7.8542         2
# 3        4      349909  21.0750         2
# 4        0  F.C. 12750  52.0000         2
# ..     ...         ...      ...       ...
# 886      0      237736  30.0708         0
# 887      0        2669   7.2292         0
# 888      0      315084   8.6625         2
# 889      0      349215   7.8958         2
# 890      0      250655  26.0000         2
#
# [891 rows x 11 columns]

# %%
plot_correlation_map( df )

# %%
df[['Pclass','Survived']].groupby(['Pclass'],as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
#df=df.drop(['Name'],axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare  Embarked
# 0        0      248740  13.0000         2
# 1        0      348123   7.6500         2
# 2        0      350050   7.8542         2
# 3        4      349909  21.0750         2
# 4        0  F.C. 12750  52.0000         2
# ..     ...         ...      ...       ...
# 886      0      237736  30.0708         0
# 887      0        2669   7.2292         0
# 888      0      315084   8.6625         2
# 889      0      349215   7.8958         2
# 890      0      250655  26.0000         2
#
# [891 rows x 11 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare  Embarked
# 0        0      248740  13.0000         2
# 1        0      348123   7.6500         2
# 2        0      350050   7.8542         2
# 3        4      349909  21.0750         2
# 4        0  F.C. 12750  52.0000         2
# ..     ...         ...      ...       ...
# 886      0      237736  30.0708         0
# 887      0        2669   7.2292         0
# 888      0      315084   8.6625         2
# 889      0      349215   7.8958         2
# 890      0      250655  26.0000         2
#
# [891 rows x 11 columns]

# %%
# title=[]
# for Name in df['Name']:
#     x=Name.find(',')
#     y=Name.find('.')
#     title.append(Name[x+1:y])

# %%
df["Title"]=df["Name"].str.extract(' ([A-Za-z]+).')

# %%
df.head(8)
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
# 5          105         0       3               Gustafsson, Mr. Anders Vilhelm
# 6          576         0       3                         Patchett, Mr. George
# 7          382         1       3                  Nakid, Miss. Maria ("Mary")
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Embarked Title
# 0    1  28.0      0      0      248740  13.0000         2    Mr
# 1    1  25.0      0      0      348123   7.6500         2    Mr
# 2    1  20.0      0      0      350050   7.8542         2    Mr
# 3    0  29.0      0      4      349909  21.0750         2   Mrs
# 4    1  31.0      1      0  F.C. 12750  52.0000         2    Mr
# 5    1  37.0      2      0     3101276   7.9250         2    Mr
# 6    1  19.0      0      0      358585  14.5000         2    Mr
# 7    0   1.0      0      2        2653  15.7417         0  Miss

# %%
df['Title']=encoder.fit_transform(df['Title'])
plot_correlation_map( df )

# %%
sns.heatmap(df.corr(),annot=True)

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }

# %%
Title_Dictionary
# Out:
# {'Capt': 'Officer',
#  'Col': 'Officer',
#  'Major': 'Officer',
#  'Dr': 'Officer',
#  'Rev': 'Officer',
#  'Jonkheer': 'Royalty',
#  'Don': 'Royalty',
#  'Sir': 'Royalty',
#  'Lady': 'Royalty',
#  'the Countess': 'Royalty',
#  'Dona': 'Royalty',
#  'Mme': 'Miss',
#  'Mlle': 'Miss',
#  'Miss': 'Miss',
#  'Ms': 'Mrs',
#  'Mr': 'Mrs',
#  'Mrs': 'Mrs',
#  'Master': 'Master'}

# %%
df.replace(Title_Dictionary,inplace=True)
#df["Title"]=df["Title"].map(Title_Dictionary)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare  Embarked Title
# 0        0      248740  13.0000         2   Mrs
# 1        0      348123   7.6500         2   Mrs
# 2        0      350050   7.8542         2   Mrs
# 3        4      349909  21.0750         2   Mrs
# 4        0  F.C. 12750  52.0000         2   Mrs
# ..     ...         ...      ...       ...   ...
# 886      0      237736  30.0708         0   Mrs
# 887      0        2669   7.2292         0   Mrs
# 888      0      315084   8.6625         2  Miss
# 889      0      349215   7.8958         2   Mrs
# 890      0      250655  26.0000         2  Miss
#
# [891 rows x 12 columns]

# %%
plot_correlation_map( df )

# %%
df["FamilySize"]=df["SibSp"]+df["Parch"]+1

# %%
df.head(8)
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
# 5          105         0       3               Gustafsson, Mr. Anders Vilhelm
# 6          576         0       3                         Patchett, Mr. George
# 7          382         1       3                  Nakid, Miss. Maria ("Mary")
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Embarked Title  FamilySize
# 0    1  28.0      0      0      248740  13.0000         2   Mrs           1
# 1    1  25.0      0      0      348123   7.6500         2   Mrs           1
# 2    1  20.0      0      0      350050   7.8542         2   Mrs           1
# 3    0  29.0      0      4      349909  21.0750         2   Mrs           5
# 4    1  31.0      1      0  F.C. 12750  52.0000         2   Mrs           2
# 5    1  37.0      2      0     3101276   7.9250         2   Mrs           3
# 6    1  19.0      0      0      358585  14.5000         2   Mrs           1
# 7    0   1.0      0      2        2653  15.7417         0  Miss           3

# %%
 this feature is useful
